# %%
#q1 An API(application programming interface) is a set of rules that allows different software apllications to communicate with each other. for eg when we use a weather app, the app uses data from a weather service through an API

# %%
#q2  advantages includes easy communications between diff applications, imporves efficiency, saves time by using existing services
#disadvantages include security risks, dependency on third party services

# %%
#q3   web api is an api that works over the internet using protocols such as HTTP
#api can work online/offline on diff protocols such as http,tcp etc but web api runs only online and only through HTTP

# %%
#q4   REST (Representational State Transfer) --> Uses HTTP methods like GET, POST, PUT, and DELETE,lightweight and easy to use,Usually exchanges data in JSON format.
#  SOAP (Simple Object Access Protocol) --> Uses XML messages,Provides built-in security and reliability.
Shortcomings of SOAP:
