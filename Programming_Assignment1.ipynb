# %%
#question 1
print('Hello Python')
# Out:
# Hello Python

# %%
#question 2
a = int(input("value1 = "))
b = int(input("value2 = "))
print(a/b , a+b)
# Out:
# value1 =  45
# value2 =  57
# 0.7894736842105263 102

# %%
#question 3
b = int(input("value1 = "))
h = int(input("value2 = "))
area = 0.5 * b * h
print("area = " ,area)
# Out:
# value1 =  45
# value2 =  57
# area =  1282.5

# %%
#question 4
x = int(input("value1 = "))
y = int(input("value2 = "))
print(x,y)
x,y = y,x
print(x,y)
# Out:
# value1 =  57
# value2 =  45
# 57 45
# 45 57

# %%
#question 5
import random
print(random.randint(0,100))
# Out:
# 41
