# %%
#question 1
* ---> expression
'hello' ---> value
-87.8 ---> value
- ---> expression
/ ---> expression
+ ---> expression
6 ---> value

# %%
#question 2
A string is a data type in which any data can be stored , enclosed in "" or '', while a variable is a container that holds a certain value.

# %%
#question 3
a) integer: represent the integers in the number system  without a fractional or decimal part, and apparently can use any arbitrarily large number. Eg- 14.0
b) string: Represents text data and is a sequence of characters enclosed in single quotes, double quotes. Eg - 14.7
c) floating point number: Represents real numbers that have a decimal point or fractional part. Eg - 'alice'

# %%
#question 4
a combination of values, variables, operators, and function calls that the Python interpreter evaluates to produce a single result is an expression.
The key characteristic of any expression is evaluation.

# %%
#question 5
a statement performs the action of assigning the value and particularly does not evaluate a value, while expression leads to evaluation of a value.

# %%
#question 6
bacon = 22
bacon = bacon + 1
print(bacon)
# Out:
# 23

# %%
#question 7
print('spam' + 'spamspam')
print('spam'*3)
# Out:
# spamspamspam
# spamspamspam

# %%
#question 8
name of a variable should not be some special character like numbers , datatypes , while , for , if etc.

# %%
#question 9
value = 47.9
a = int(value)
print(a)

value1 = 47
b = float(value1)
print(b)

value2 = 88
c = str(value2)
print(c)
print(type(c))
# Out:
# 47
# 47.0
# 88
# <class 'str'>

# %%
#question 10
it has a problem because concatenation is allowed for same datatype only and here we have added two strings with a integer causing an erorr.
#'I have eaten' + 99 +  'burritos' ----->
'I have eaten' + str(99) + 'burritos'
